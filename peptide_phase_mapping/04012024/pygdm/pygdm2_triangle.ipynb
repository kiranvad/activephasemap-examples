# %%
from pyGDM2 import structures
from pyGDM2 import materials
from pyGDM2 import fields
from pyGDM2 import propagators
from pyGDM2 import core
from pyGDM2 import linear
from pyGDM2 import tools
import numpy as np 
import matplotlib.pyplot as plt

# %%
length = 200 # in nm
height = 10 # in nm
step = 10 # in nm
geometry = structures.polygon(step, {"N":3, "S":length/step}, H=height/step, mesh='hex')

material = materials.gold()
struct = structures.struct(step, geometry, material)

field_generator = fields.plane_wave
wavelengths = np.linspace(400, 900, 101)
field_kwargs = dict(theta=[0], inc_angle=180)

efield = fields.efield(field_generator, wavelengths=wavelengths, kwargs=field_kwargs)
n1 = n2 = 1.33
dyads = propagators.DyadsQuasistatic123(n1=n1, n2=n2)
sim = core.simulation(struct, efield, dyads)
# Out:
# structure initialization - automatic mesh detection: hex
# structure initialization - consistency check: 1261/1261 dipoles valid

# %%
## --- run the simulation
sim.scatter()
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# timing for wl=400.00nm - setup: EE 2637.1ms, inv.: 1267.3ms, repropa.: 363.6ms (1 field configs), tot: 4268.3ms
# timing for wl=405.00nm - setup: EE 104.8ms, inv.: 1231.6ms, repropa.: 38.1ms (1 field configs), tot: 1374.7ms
# timing for wl=410.00nm - setup: EE 108.2ms, inv.: 1203.2ms, repropa.: 34.6ms (1 field configs), tot: 1346.3ms
# timing for wl=415.00nm - setup: EE 110.4ms, inv.: 1308.1ms, repropa.: 34.7ms (1 field configs), tot: 1453.4ms
# timing for wl=420.00nm - setup: EE 113.6ms, inv.: 1282.6ms, repropa.: 40.9ms (1 field configs), tot: 1437.3ms
# timing for wl=425.00nm - setup: EE 130.4ms, inv.: 1338.7ms, repropa.: 36.5ms (1 field configs), tot: 1505.9ms
# timing for wl=430.00nm - setup: EE 104.5ms, inv.: 1296.1ms, repropa.: 37.7ms (1 field configs), tot: 1438.4ms
# timing for wl=435.00nm - setup: EE 145.9ms, inv.: 1289.0ms, repropa.: 34.5ms (1 field configs), tot: 1469.7ms
# timing for wl=440.00nm - setup: EE 109.6ms, inv.: 1280.3ms, repropa.: 35.9ms (1 field configs), tot: 1425.9ms
# timing for wl=445.00nm - setup: EE 105.2ms, inv.: 1195.1ms, repropa.: 34.7ms (1 field configs), tot: 1335.3ms
# timing for wl=450.00nm - setup: EE 109.6ms, inv.: 1192.5ms, repropa.: 34.4ms (1 field configs), tot: 1336.9ms
# timing for wl=455.00nm - setup: EE 114.9ms, inv.: 1198.8ms, repropa.: 36.0ms (1 field configs), tot: 1349.9ms
# timing for wl=460.00nm - setup: EE 110.3ms, inv.: 1195.6ms, repropa.: 34.7ms (1 field configs), tot: 1340.8ms
# timing for wl=465.00nm - setup: EE 101.0ms, inv.: 1347.2ms, repropa.: 37.4ms (1 field configs), tot: 1485.9ms
# timing for wl=470.00nm - setup: EE 115.1ms, inv.: 1294.6ms, repropa.: 40.9ms (1 field configs), tot: 1450.8ms
# timing for wl=475.00nm - setup: EE 116.4ms, inv.: 1340.8ms, repropa.: 39.9ms (1 field configs), tot: 1497.3ms
# timing for wl=480.00nm - setup: EE 121.4ms, inv.: 1310.8ms, repropa.: 34.4ms (1 field configs), tot: 1466.8ms
# timing for wl=485.00nm - setup: EE 108.5ms, inv.: 1175.8ms, repropa.: 37.9ms (1 field configs), tot: 1322.4ms
# timing for wl=490.00nm - setup: EE 106.0ms, inv.: 1224.2ms, repropa.: 34.6ms (1 field configs), tot: 1365.1ms
# timing for wl=495.00nm - setup: EE 101.5ms, inv.: 1198.7ms, repropa.: 34.7ms (1 field configs), tot: 1335.1ms
# timing for wl=500.00nm - setup: EE 109.2ms, inv.: 1167.9ms, repropa.: 34.5ms (1 field configs), tot: 1311.7ms
# timing for wl=505.00nm - setup: EE 113.5ms, inv.: 1256.5ms, repropa.: 34.8ms (1 field configs), tot: 1405.0ms
# timing for wl=510.00nm - setup: EE 102.0ms, inv.: 1200.2ms, repropa.: 34.4ms (1 field configs), tot: 1336.8ms
# timing for wl=515.00nm - setup: EE 102.5ms, inv.: 1201.0ms, repropa.: 34.2ms (1 field configs), tot: 1338.0ms
# timing for wl=520.00nm - setup: EE 106.4ms, inv.: 1211.7ms, repropa.: 36.9ms (1 field configs), tot: 1355.3ms
# timing for wl=525.00nm - setup: EE 111.0ms, inv.: 1242.8ms, repropa.: 34.8ms (1 field configs), tot: 1388.9ms
# timing for wl=530.00nm - setup: EE 102.7ms, inv.: 1205.3ms, repropa.: 38.1ms (1 field configs), tot: 1346.3ms
# timing for wl=535.00nm - setup: EE 118.4ms, inv.: 1296.2ms, repropa.: 38.7ms (1 field configs), tot: 1453.7ms
# timing for wl=540.00nm - setup: EE 121.7ms, inv.: 1335.2ms, repropa.: 38.2ms (1 field configs), tot: 1495.2ms
# timing for wl=545.00nm - setup: EE 126.7ms, inv.: 1245.9ms, repropa.: 34.6ms (1 field configs), tot: 1407.3ms
# timing for wl=550.00nm - setup: EE 118.7ms, inv.: 1219.0ms, repropa.: 34.4ms (1 field configs), tot: 1372.3ms
# timing for wl=555.00nm - setup: EE 103.7ms, inv.: 1245.2ms, repropa.: 34.9ms (1 field configs), tot: 1384.0ms
# timing for wl=560.00nm - setup: EE 102.0ms, inv.: 1205.9ms, repropa.: 35.4ms (1 field configs), tot: 1343.5ms
# timing for wl=565.00nm - setup: EE 106.8ms, inv.: 1224.8ms, repropa.: 34.5ms (1 field configs), tot: 1366.4ms
# timing for wl=570.00nm - setup: EE 103.0ms, inv.: 1211.6ms, repropa.: 34.5ms (1 field configs), tot: 1349.3ms
# timing for wl=575.00nm - setup: EE 101.6ms, inv.: 1234.3ms, repropa.: 34.4ms (1 field configs), tot: 1370.6ms
# timing for wl=580.00nm - setup: EE 104.2ms, inv.: 1207.9ms, repropa.: 34.5ms (1 field configs), tot: 1346.8ms
# timing for wl=585.00nm - setup: EE 99.3ms, inv.: 1192.0ms, repropa.: 36.0ms (1 field configs), tot: 1327.5ms
# timing for wl=590.00nm - setup: EE 107.6ms, inv.: 1214.9ms, repropa.: 35.4ms (1 field configs), tot: 1358.1ms
# timing for wl=595.00nm - setup: EE 104.5ms, inv.: 1181.9ms, repropa.: 34.4ms (1 field configs), tot: 1320.9ms
# timing for wl=600.00nm - setup: EE 104.2ms, inv.: 1213.1ms, repropa.: 34.4ms (1 field configs), tot: 1351.9ms
# timing for wl=605.00nm - setup: EE 101.7ms, inv.: 1212.2ms, repropa.: 34.9ms (1 field configs), tot: 1349.0ms
# timing for wl=610.00nm - setup: EE 109.1ms, inv.: 1185.1ms, repropa.: 34.1ms (1 field configs), tot: 1328.6ms
# timing for wl=615.00nm - setup: EE 106.7ms, inv.: 1252.7ms, repropa.: 34.0ms (1 field configs), tot: 1393.5ms
# timing for wl=620.00nm - setup: EE 103.5ms, inv.: 1192.2ms, repropa.: 34.5ms (1 field configs), tot: 1330.4ms
# timing for wl=625.00nm - setup: EE 103.6ms, inv.: 1194.6ms, repropa.: 34.4ms (1 field configs), tot: 1332.7ms
# timing for wl=630.00nm - setup: EE 109.2ms, inv.: 1275.8ms, repropa.: 34.5ms (1 field configs), tot: 1419.7ms
# timing for wl=635.00nm - setup: EE 106.9ms, inv.: 1267.4ms, repropa.: 34.7ms (1 field configs), tot: 1409.2ms
# timing for wl=640.00nm - setup: EE 104.2ms, inv.: 1202.5ms, repropa.: 34.4ms (1 field configs), tot: 1341.4ms
# timing for wl=645.00nm - setup: EE 114.5ms, inv.: 1625.8ms, repropa.: 35.6ms (1 field configs), tot: 1776.0ms
# timing for wl=650.00nm - setup: EE 110.9ms, inv.: 1506.0ms, repropa.: 34.2ms (1 field configs), tot: 1651.3ms
# timing for wl=655.00nm - setup: EE 103.3ms, inv.: 1868.8ms, repropa.: 44.9ms (1 field configs), tot: 2017.2ms
# timing for wl=660.00nm - setup: EE 112.5ms, inv.: 1216.7ms, repropa.: 34.1ms (1 field configs), tot: 1363.5ms
# timing for wl=665.00nm - setup: EE 107.4ms, inv.: 1283.4ms, repropa.: 39.0ms (1 field configs), tot: 1430.2ms
# timing for wl=670.00nm - setup: EE 168.3ms, inv.: 1386.0ms, repropa.: 35.0ms (1 field configs), tot: 1589.7ms
# timing for wl=675.00nm - setup: EE 110.9ms, inv.: 1301.9ms, repropa.: 34.3ms (1 field configs), tot: 1447.4ms
# timing for wl=680.00nm - setup: EE 102.6ms, inv.: 1223.2ms, repropa.: 36.9ms (1 field configs), tot: 1362.9ms
# timing for wl=685.00nm - setup: EE 111.1ms, inv.: 1244.2ms, repropa.: 34.5ms (1 field configs), tot: 1390.0ms
# timing for wl=690.00nm - setup: EE 101.4ms, inv.: 1345.4ms, repropa.: 38.1ms (1 field configs), tot: 1485.2ms
# timing for wl=695.00nm - setup: EE 104.6ms, inv.: 1549.5ms, repropa.: 36.6ms (1 field configs), tot: 1691.0ms
# timing for wl=700.00nm - setup: EE 116.4ms, inv.: 1546.4ms, repropa.: 34.6ms (1 field configs), tot: 1697.5ms
# timing for wl=705.00nm - setup: EE 101.0ms, inv.: 1511.3ms, repropa.: 35.9ms (1 field configs), tot: 1648.5ms
# timing for wl=710.00nm - setup: EE 170.6ms, inv.: 1285.3ms, repropa.: 34.8ms (1 field configs), tot: 1491.0ms
# timing for wl=715.00nm - setup: EE 107.1ms, inv.: 1474.7ms, repropa.: 36.7ms (1 field configs), tot: 1618.8ms
# timing for wl=720.00nm - setup: EE 117.1ms, inv.: 1244.4ms, repropa.: 36.1ms (1 field configs), tot: 1397.9ms
# timing for wl=725.00nm - setup: EE 103.1ms, inv.: 1215.4ms, repropa.: 34.7ms (1 field configs), tot: 1353.3ms
# timing for wl=730.00nm - setup: EE 107.6ms, inv.: 1242.1ms, repropa.: 35.4ms (1 field configs), tot: 1385.3ms
# timing for wl=735.00nm - setup: EE 156.2ms, inv.: 1453.6ms, repropa.: 36.6ms (1 field configs), tot: 1646.6ms
# timing for wl=740.00nm - setup: EE 110.8ms, inv.: 1228.3ms, repropa.: 37.4ms (1 field configs), tot: 1376.7ms
# timing for wl=745.00nm - setup: EE 112.5ms, inv.: 1269.4ms, repropa.: 34.4ms (1 field configs), tot: 1416.5ms
# timing for wl=750.00nm - setup: EE 105.5ms, inv.: 1238.1ms, repropa.: 36.4ms (1 field configs), tot: 1380.3ms
# timing for wl=755.00nm - setup: EE 106.9ms, inv.: 1236.9ms, repropa.: 34.2ms (1 field configs), tot: 1378.3ms
# timing for wl=760.00nm - setup: EE 110.4ms, inv.: 1256.3ms, repropa.: 34.1ms (1 field configs), tot: 1401.0ms
# timing for wl=765.00nm - setup: EE 108.9ms, inv.: 1204.8ms, repropa.: 34.2ms (1 field configs), tot: 1348.0ms
# timing for wl=770.00nm - setup: EE 101.2ms, inv.: 1221.8ms, repropa.: 34.0ms (1 field configs), tot: 1357.1ms
# timing for wl=775.00nm - setup: EE 105.6ms, inv.: 1242.2ms, repropa.: 34.4ms (1 field configs), tot: 1382.4ms
# timing for wl=780.00nm - setup: EE 103.7ms, inv.: 1218.8ms, repropa.: 34.3ms (1 field configs), tot: 1357.1ms
# timing for wl=785.00nm - setup: EE 105.3ms, inv.: 1227.4ms, repropa.: 34.6ms (1 field configs), tot: 1367.5ms
# timing for wl=790.00nm - setup: EE 105.9ms, inv.: 1231.1ms, repropa.: 34.3ms (1 field configs), tot: 1371.5ms
# timing for wl=795.00nm - setup: EE 103.0ms, inv.: 1401.3ms, repropa.: 34.3ms (1 field configs), tot: 1538.9ms
# timing for wl=800.00nm - setup: EE 105.2ms, inv.: 1232.2ms, repropa.: 34.3ms (1 field configs), tot: 1371.9ms
# timing for wl=805.00nm - setup: EE 106.7ms, inv.: 1230.3ms, repropa.: 34.5ms (1 field configs), tot: 1371.6ms
# timing for wl=810.00nm - setup: EE 106.0ms, inv.: 1386.4ms, repropa.: 36.5ms (1 field configs), tot: 1529.1ms
# timing for wl=815.00nm - setup: EE 107.7ms, inv.: 1238.9ms, repropa.: 59.7ms (1 field configs), tot: 1406.4ms
# timing for wl=820.00nm - setup: EE 107.3ms, inv.: 1216.1ms, repropa.: 34.2ms (1 field configs), tot: 1357.7ms
# timing for wl=825.00nm - setup: EE 112.0ms, inv.: 1233.5ms, repropa.: 34.0ms (1 field configs), tot: 1379.7ms
# timing for wl=830.00nm - setup: EE 106.8ms, inv.: 1211.6ms, repropa.: 34.5ms (1 field configs), tot: 1353.1ms
# timing for wl=835.00nm - setup: EE 104.7ms, inv.: 1396.1ms, repropa.: 36.3ms (1 field configs), tot: 1537.3ms
# timing for wl=840.00nm - setup: EE 109.1ms, inv.: 1224.1ms, repropa.: 34.3ms (1 field configs), tot: 1367.7ms
# timing for wl=845.00nm - setup: EE 108.2ms, inv.: 1251.8ms, repropa.: 35.2ms (1 field configs), tot: 1395.4ms
# timing for wl=850.00nm - setup: EE 106.1ms, inv.: 1237.9ms, repropa.: 34.2ms (1 field configs), tot: 1378.3ms
# timing for wl=855.00nm - setup: EE 104.8ms, inv.: 1236.7ms, repropa.: 34.3ms (1 field configs), tot: 1376.1ms
# timing for wl=860.00nm - setup: EE 219.4ms, inv.: 1298.2ms, repropa.: 35.0ms (1 field configs), tot: 1553.1ms
# timing for wl=865.00nm - setup: EE 100.0ms, inv.: 1212.3ms, repropa.: 38.0ms (1 field configs), tot: 1350.5ms
# timing for wl=870.00nm - setup: EE 103.0ms, inv.: 1264.4ms, repropa.: 34.6ms (1 field configs), tot: 1402.1ms
# timing for wl=875.00nm - setup: EE 104.3ms, inv.: 1282.6ms, repropa.: 33.8ms (1 field configs), tot: 1421.2ms
# timing for wl=880.00nm - setup: EE 233.4ms, inv.: 1242.4ms, repropa.: 34.4ms (1 field configs), tot: 1510.4ms
# timing for wl=885.00nm - setup: EE 102.7ms, inv.: 1189.2ms, repropa.: 36.9ms (1 field configs), tot: 1329.0ms
# timing for wl=890.00nm - setup: EE 101.2ms, inv.: 1196.0ms, repropa.: 34.3ms (1 field configs), tot: 1331.7ms
# timing for wl=895.00nm - setup: EE 108.1ms, inv.: 1222.9ms, repropa.: 34.1ms (1 field configs), tot: 1365.4ms
# timing for wl=900.00nm - setup: EE 100.6ms, inv.: 1237.0ms, repropa.: 34.5ms (1 field configs), tot: 1372.2ms
# 1

# %%
field_kwargs = tools.get_possible_field_params_spectra(sim)
for i, conf in enumerate(field_kwargs):
    print("config", i, ":", conf)
# Out:
# config 0 : {'inc_angle': 180, 'theta': 0}

# %%
wl, spectrum = tools.calculate_spectrum(sim, field_kwargs[0], linear.extinct)
area_geom = tools.get_geometric_cross_section(sim)

# %%
fig = plt.figure(figsize=(4*2, 4))
fig.subplots_adjust(wspace=0.5)
ax = fig.add_subplot(1,2,1, projection="3d")

ax.scatter(geometry[:,0], geometry[:,1], geometry[:,2])
ax.set_xlabel("x (nm)")
ax.set_ylabel("y (nm)")
ax.set_zlabel("z (nm)")
ax.axes.set_zlim3d(bottom=-100.0, top=100.0)

ax = fig.add_subplot(1,2,2)
ax.plot(wl, spectrum.T[0]/area_geom, 'g-', label='ext.')
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("cross section")
plt.savefig("./traingle.png")
plt.show()

# %%
from scipy.interpolate import splev, splrep

y = spectrum.T[0]/area_geom
spline = splrep(wl, y)
xt = np.linspace(400, 900, 100) # upsample to 100 points
yt = splev(xt, spline)

fig, ax = plt.subplots()
ax.scatter(wl, y, s=10, color='k')
ax.plot(xt, yt)
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("cross section")
plt.show()

# %%
np.savez("./target_triangle.npz", y=yt, x=xt)
