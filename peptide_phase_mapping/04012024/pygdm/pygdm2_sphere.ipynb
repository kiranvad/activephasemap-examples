# %%
from pyGDM2 import structures
from pyGDM2 import materials
from pyGDM2 import fields
from pyGDM2 import propagators
from pyGDM2 import core
from pyGDM2 import linear
from pyGDM2 import tools
import numpy as np 
import matplotlib.pyplot as plt

# %%
target_radius = 10 # in nm
step = 2.0 # in nm
geometry = structures.sphere(step, 
                             R=target_radius/step,
                             mesh='hex') 

material = materials.gold()
struct = structures.struct(step, geometry, material)

field_generator = fields.plane_wave
wavelengths = np.linspace(400, 900, 101)
field_kwargs = dict(theta=[0], inc_angle=180)

efield = fields.efield(field_generator, wavelengths=wavelengths, kwargs=field_kwargs)
n1 = n2 = 1.33
dyads = propagators.DyadsQuasistatic123(n1=n1, n2=n2)
sim = core.simulation(struct, efield, dyads)
# Out:
# structure initialization - automatic mesh detection: hex
# structure initialization - consistency check: 853/853 dipoles valid

# %%
## --- run the simulation
sim.scatter()
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# timing for wl=400.00nm - setup: EE 5379.2ms, inv.: 448.9ms, repropa.: 3127.0ms (1 field configs), tot: 8955.3ms
# timing for wl=405.00nm - setup: EE 51.5ms, inv.: 408.6ms, repropa.: 22.4ms (1 field configs), tot: 482.8ms
# timing for wl=410.00nm - setup: EE 55.5ms, inv.: 399.6ms, repropa.: 22.4ms (1 field configs), tot: 477.8ms
# timing for wl=415.00nm - setup: EE 57.1ms, inv.: 407.1ms, repropa.: 22.5ms (1 field configs), tot: 486.9ms
# timing for wl=420.00nm - setup: EE 52.1ms, inv.: 401.0ms, repropa.: 22.4ms (1 field configs), tot: 475.7ms
# timing for wl=425.00nm - setup: EE 57.1ms, inv.: 413.5ms, repropa.: 22.4ms (1 field configs), tot: 493.2ms
# timing for wl=430.00nm - setup: EE 51.8ms, inv.: 408.8ms, repropa.: 22.2ms (1 field configs), tot: 483.0ms
# timing for wl=435.00nm - setup: EE 53.1ms, inv.: 407.8ms, repropa.: 22.6ms (1 field configs), tot: 483.6ms
# timing for wl=440.00nm - setup: EE 53.4ms, inv.: 404.4ms, repropa.: 22.3ms (1 field configs), tot: 480.3ms
# timing for wl=445.00nm - setup: EE 52.1ms, inv.: 410.7ms, repropa.: 22.3ms (1 field configs), tot: 485.3ms
# timing for wl=450.00nm - setup: EE 54.2ms, inv.: 415.2ms, repropa.: 22.4ms (1 field configs), tot: 492.0ms
# timing for wl=455.00nm - setup: EE 52.5ms, inv.: 412.6ms, repropa.: 22.2ms (1 field configs), tot: 487.5ms
# timing for wl=460.00nm - setup: EE 52.5ms, inv.: 415.6ms, repropa.: 22.3ms (1 field configs), tot: 490.7ms
# timing for wl=465.00nm - setup: EE 53.4ms, inv.: 417.8ms, repropa.: 22.3ms (1 field configs), tot: 493.8ms
# timing for wl=470.00nm - setup: EE 51.5ms, inv.: 410.8ms, repropa.: 22.3ms (1 field configs), tot: 484.8ms
# timing for wl=475.00nm - setup: EE 57.9ms, inv.: 406.6ms, repropa.: 22.2ms (1 field configs), tot: 486.9ms
# timing for wl=480.00nm - setup: EE 56.8ms, inv.: 404.9ms, repropa.: 22.2ms (1 field configs), tot: 484.1ms
# timing for wl=485.00nm - setup: EE 53.4ms, inv.: 410.0ms, repropa.: 22.3ms (1 field configs), tot: 485.9ms
# timing for wl=490.00nm - setup: EE 51.9ms, inv.: 438.5ms, repropa.: 22.2ms (1 field configs), tot: 512.8ms
# timing for wl=495.00nm - setup: EE 52.9ms, inv.: 404.4ms, repropa.: 22.3ms (1 field configs), tot: 479.9ms
# timing for wl=500.00nm - setup: EE 54.4ms, inv.: 418.4ms, repropa.: 22.2ms (1 field configs), tot: 495.3ms
# timing for wl=505.00nm - setup: EE 53.2ms, inv.: 414.6ms, repropa.: 22.4ms (1 field configs), tot: 490.4ms
# timing for wl=510.00nm - setup: EE 54.6ms, inv.: 413.9ms, repropa.: 23.5ms (1 field configs), tot: 492.2ms
# timing for wl=515.00nm - setup: EE 53.8ms, inv.: 415.2ms, repropa.: 22.4ms (1 field configs), tot: 491.6ms
# timing for wl=520.00nm - setup: EE 52.6ms, inv.: 439.5ms, repropa.: 22.5ms (1 field configs), tot: 514.8ms
# timing for wl=525.00nm - setup: EE 58.6ms, inv.: 420.4ms, repropa.: 22.2ms (1 field configs), tot: 501.4ms
# timing for wl=530.00nm - setup: EE 53.9ms, inv.: 400.7ms, repropa.: 22.7ms (1 field configs), tot: 477.5ms
# timing for wl=535.00nm - setup: EE 54.9ms, inv.: 405.5ms, repropa.: 22.6ms (1 field configs), tot: 483.2ms
# timing for wl=540.00nm - setup: EE 55.8ms, inv.: 439.2ms, repropa.: 22.8ms (1 field configs), tot: 518.1ms
# timing for wl=545.00nm - setup: EE 59.3ms, inv.: 411.2ms, repropa.: 26.1ms (1 field configs), tot: 496.7ms
# timing for wl=550.00nm - setup: EE 51.9ms, inv.: 409.9ms, repropa.: 22.7ms (1 field configs), tot: 484.8ms
# timing for wl=555.00nm - setup: EE 51.7ms, inv.: 401.2ms, repropa.: 22.7ms (1 field configs), tot: 476.0ms
# timing for wl=560.00nm - setup: EE 53.6ms, inv.: 412.5ms, repropa.: 22.5ms (1 field configs), tot: 488.8ms
# timing for wl=565.00nm - setup: EE 55.3ms, inv.: 405.0ms, repropa.: 24.0ms (1 field configs), tot: 484.5ms
# timing for wl=570.00nm - setup: EE 53.1ms, inv.: 403.3ms, repropa.: 22.2ms (1 field configs), tot: 478.9ms
# timing for wl=575.00nm - setup: EE 57.7ms, inv.: 405.6ms, repropa.: 22.5ms (1 field configs), tot: 486.0ms
# timing for wl=580.00nm - setup: EE 50.0ms, inv.: 417.7ms, repropa.: 22.6ms (1 field configs), tot: 490.4ms
# timing for wl=585.00nm - setup: EE 53.5ms, inv.: 410.2ms, repropa.: 22.5ms (1 field configs), tot: 486.5ms
# timing for wl=590.00nm - setup: EE 58.3ms, inv.: 414.8ms, repropa.: 22.5ms (1 field configs), tot: 495.8ms
# timing for wl=595.00nm - setup: EE 56.0ms, inv.: 390.3ms, repropa.: 22.4ms (1 field configs), tot: 468.9ms
# timing for wl=600.00nm - setup: EE 54.4ms, inv.: 416.2ms, repropa.: 22.4ms (1 field configs), tot: 493.3ms
# timing for wl=605.00nm - setup: EE 55.6ms, inv.: 404.1ms, repropa.: 22.1ms (1 field configs), tot: 482.0ms
# timing for wl=610.00nm - setup: EE 53.8ms, inv.: 404.8ms, repropa.: 22.2ms (1 field configs), tot: 481.1ms
# timing for wl=615.00nm - setup: EE 53.0ms, inv.: 420.1ms, repropa.: 22.8ms (1 field configs), tot: 496.1ms
# timing for wl=620.00nm - setup: EE 51.5ms, inv.: 411.4ms, repropa.: 22.4ms (1 field configs), tot: 485.4ms
# timing for wl=625.00nm - setup: EE 57.9ms, inv.: 407.7ms, repropa.: 22.3ms (1 field configs), tot: 488.0ms
# timing for wl=630.00nm - setup: EE 54.7ms, inv.: 422.0ms, repropa.: 22.3ms (1 field configs), tot: 499.1ms
# timing for wl=635.00nm - setup: EE 54.4ms, inv.: 404.4ms, repropa.: 22.4ms (1 field configs), tot: 481.5ms
# timing for wl=640.00nm - setup: EE 53.3ms, inv.: 414.8ms, repropa.: 22.6ms (1 field configs), tot: 490.9ms
# timing for wl=645.00nm - setup: EE 54.8ms, inv.: 411.3ms, repropa.: 22.6ms (1 field configs), tot: 489.0ms
# timing for wl=650.00nm - setup: EE 50.3ms, inv.: 406.2ms, repropa.: 22.4ms (1 field configs), tot: 479.1ms
# timing for wl=655.00nm - setup: EE 53.3ms, inv.: 418.9ms, repropa.: 22.2ms (1 field configs), tot: 494.6ms
# timing for wl=660.00nm - setup: EE 51.3ms, inv.: 415.8ms, repropa.: 22.3ms (1 field configs), tot: 489.6ms
# timing for wl=665.00nm - setup: EE 54.0ms, inv.: 408.1ms, repropa.: 22.5ms (1 field configs), tot: 484.9ms
# timing for wl=670.00nm - setup: EE 53.4ms, inv.: 404.8ms, repropa.: 26.3ms (1 field configs), tot: 484.7ms
# timing for wl=675.00nm - setup: EE 54.3ms, inv.: 408.6ms, repropa.: 22.5ms (1 field configs), tot: 485.6ms
# timing for wl=680.00nm - setup: EE 56.6ms, inv.: 406.8ms, repropa.: 22.2ms (1 field configs), tot: 485.9ms
# timing for wl=685.00nm - setup: EE 54.9ms, inv.: 404.0ms, repropa.: 22.3ms (1 field configs), tot: 481.4ms
# timing for wl=690.00nm - setup: EE 56.4ms, inv.: 403.7ms, repropa.: 22.3ms (1 field configs), tot: 482.6ms
# timing for wl=695.00nm - setup: EE 50.9ms, inv.: 410.4ms, repropa.: 22.2ms (1 field configs), tot: 483.7ms
# timing for wl=700.00nm - setup: EE 52.8ms, inv.: 400.0ms, repropa.: 22.2ms (1 field configs), tot: 475.1ms
# timing for wl=705.00nm - setup: EE 54.9ms, inv.: 401.9ms, repropa.: 22.4ms (1 field configs), tot: 479.5ms
# timing for wl=710.00nm - setup: EE 52.7ms, inv.: 399.4ms, repropa.: 22.4ms (1 field configs), tot: 474.8ms
# timing for wl=715.00nm - setup: EE 53.3ms, inv.: 415.3ms, repropa.: 22.5ms (1 field configs), tot: 491.3ms
# timing for wl=720.00nm - setup: EE 53.1ms, inv.: 416.5ms, repropa.: 22.3ms (1 field configs), tot: 492.1ms
# timing for wl=725.00nm - setup: EE 53.9ms, inv.: 414.2ms, repropa.: 22.6ms (1 field configs), tot: 491.0ms
# timing for wl=730.00nm - setup: EE 53.8ms, inv.: 409.6ms, repropa.: 22.7ms (1 field configs), tot: 486.4ms
# timing for wl=735.00nm - setup: EE 50.7ms, inv.: 414.4ms, repropa.: 22.3ms (1 field configs), tot: 487.6ms
# timing for wl=740.00nm - setup: EE 52.2ms, inv.: 409.0ms, repropa.: 22.3ms (1 field configs), tot: 483.7ms
# timing for wl=745.00nm - setup: EE 53.4ms, inv.: 409.1ms, repropa.: 22.6ms (1 field configs), tot: 485.4ms
# timing for wl=750.00nm - setup: EE 53.0ms, inv.: 410.8ms, repropa.: 22.0ms (1 field configs), tot: 486.3ms
# timing for wl=755.00nm - setup: EE 54.1ms, inv.: 405.9ms, repropa.: 22.9ms (1 field configs), tot: 483.2ms
# timing for wl=760.00nm - setup: EE 51.7ms, inv.: 406.0ms, repropa.: 22.4ms (1 field configs), tot: 480.3ms
# timing for wl=765.00nm - setup: EE 54.1ms, inv.: 434.3ms, repropa.: 22.5ms (1 field configs), tot: 511.1ms
# timing for wl=770.00nm - setup: EE 54.7ms, inv.: 409.7ms, repropa.: 22.2ms (1 field configs), tot: 486.9ms
# timing for wl=775.00nm - setup: EE 53.0ms, inv.: 406.8ms, repropa.: 22.5ms (1 field configs), tot: 482.6ms
# timing for wl=780.00nm - setup: EE 54.6ms, inv.: 410.4ms, repropa.: 22.4ms (1 field configs), tot: 487.5ms
# timing for wl=785.00nm - setup: EE 53.9ms, inv.: 406.8ms, repropa.: 22.5ms (1 field configs), tot: 483.4ms
# timing for wl=790.00nm - setup: EE 52.8ms, inv.: 411.6ms, repropa.: 22.4ms (1 field configs), tot: 487.0ms
# timing for wl=795.00nm - setup: EE 52.7ms, inv.: 405.7ms, repropa.: 22.5ms (1 field configs), tot: 481.2ms
# timing for wl=800.00nm - setup: EE 53.6ms, inv.: 421.8ms, repropa.: 22.1ms (1 field configs), tot: 497.8ms
# timing for wl=805.00nm - setup: EE 53.1ms, inv.: 400.5ms, repropa.: 22.7ms (1 field configs), tot: 476.5ms
# timing for wl=810.00nm - setup: EE 55.6ms, inv.: 412.5ms, repropa.: 22.4ms (1 field configs), tot: 490.7ms
# timing for wl=815.00nm - setup: EE 53.5ms, inv.: 404.3ms, repropa.: 22.6ms (1 field configs), tot: 480.6ms
# timing for wl=820.00nm - setup: EE 54.0ms, inv.: 413.8ms, repropa.: 22.6ms (1 field configs), tot: 490.6ms
# timing for wl=825.00nm - setup: EE 55.4ms, inv.: 414.5ms, repropa.: 22.7ms (1 field configs), tot: 492.8ms
# timing for wl=830.00nm - setup: EE 54.8ms, inv.: 424.2ms, repropa.: 22.3ms (1 field configs), tot: 501.5ms
# timing for wl=835.00nm - setup: EE 56.4ms, inv.: 409.3ms, repropa.: 22.2ms (1 field configs), tot: 488.1ms
# timing for wl=840.00nm - setup: EE 53.9ms, inv.: 409.1ms, repropa.: 22.4ms (1 field configs), tot: 485.6ms
# timing for wl=845.00nm - setup: EE 52.8ms, inv.: 408.0ms, repropa.: 22.4ms (1 field configs), tot: 483.4ms
# timing for wl=850.00nm - setup: EE 52.8ms, inv.: 404.5ms, repropa.: 22.4ms (1 field configs), tot: 480.0ms
# timing for wl=855.00nm - setup: EE 58.8ms, inv.: 405.5ms, repropa.: 22.5ms (1 field configs), tot: 487.0ms
# timing for wl=860.00nm - setup: EE 55.2ms, inv.: 408.2ms, repropa.: 22.6ms (1 field configs), tot: 486.1ms
# timing for wl=865.00nm - setup: EE 49.6ms, inv.: 403.3ms, repropa.: 22.4ms (1 field configs), tot: 475.7ms
# timing for wl=870.00nm - setup: EE 55.7ms, inv.: 397.3ms, repropa.: 22.5ms (1 field configs), tot: 475.9ms
# timing for wl=875.00nm - setup: EE 52.5ms, inv.: 412.5ms, repropa.: 22.4ms (1 field configs), tot: 487.6ms
# timing for wl=880.00nm - setup: EE 56.3ms, inv.: 407.9ms, repropa.: 22.5ms (1 field configs), tot: 486.9ms
# timing for wl=885.00nm - setup: EE 50.6ms, inv.: 408.4ms, repropa.: 22.3ms (1 field configs), tot: 481.5ms
# timing for wl=890.00nm - setup: EE 52.7ms, inv.: 407.1ms, repropa.: 22.1ms (1 field configs), tot: 482.1ms
# timing for wl=895.00nm - setup: EE 53.2ms, inv.: 406.6ms, repropa.: 22.6ms (1 field configs), tot: 482.7ms
# timing for wl=900.00nm - setup: EE 54.8ms, inv.: 408.3ms, repropa.: 22.5ms (1 field configs), tot: 485.8ms
# 1

# %%
field_kwargs = tools.get_possible_field_params_spectra(sim)
for i, conf in enumerate(field_kwargs):
    print("config", i, ":", conf)
# Out:
# config 0 : {'inc_angle': 180, 'theta': 0}

# %%
wl, spectrum = tools.calculate_spectrum(sim, field_kwargs[0], linear.extinct)
area_geom = tools.get_geometric_cross_section(sim)

# %%
fig = plt.figure(figsize=(4*2, 4))
fig.subplots_adjust(wspace=0.5)
ax = fig.add_subplot(1,2,1, projection="3d")

ax.scatter(geometry[:,0], geometry[:,1], geometry[:,2])
ax.set_xlabel("x (nm)")
ax.set_ylabel("y (nm)")
ax.set_zlabel("z (nm)")

ax = fig.add_subplot(1,2,2)
ax.plot(wl, spectrum.T[0]/area_geom, 'g-', label='ext.')
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("cross section")
plt.savefig("./sphere.png")
plt.show()

# %%
from scipy.interpolate import splev, splrep

y = spectrum.T[0]/area_geom
spline = splrep(wl, y)
xt = np.linspace(400, 900, 100) # upsample to 100 points
yt = splev(xt, spline)

fig, ax = plt.subplots()
ax.scatter(wl, y, s=10, color='k')
ax.plot(xt, yt)
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("cross section")
plt.show()

# %%
np.savez("./target_sphere.npz", y=yt, x=xt)
