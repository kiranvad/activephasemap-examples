# %%
from opentrons.simulate import get_protocol_api
import json 
import pandas as pd 

protocol = get_protocol_api('2.18')
CUSTOM_LABWARE_PATH = "../opentrons_custom_labware/"
protocol.home()
# Out:
# /Users/pozzolabadmin/.opentrons/robot_settings.json not found. Loading defaults
# Deck calibration not found.
# /Users/pozzolabadmin/.opentrons/deck_calibration.json not found. Loading defaults

# %%
# load all the labware modules
tiprack_300 = protocol.load_labware(
    load_name="opentrons_96_tiprack_300ul",
    location=1)

p300 = protocol.load_instrument(
    instrument_name="p300_single_gen2",
    mount="right",
    tip_racks=[tiprack_300]
    )

tiprack_20 = protocol.load_labware(
    load_name="opentrons_96_tiprack_20ul",
    location=2)

p20 = protocol.load_instrument(
    instrument_name="p20_single_gen2",
    mount="left",
    tip_racks=[tiprack_20]
    )

with open(CUSTOM_LABWARE_PATH+'20mlscintillation_12_wellplate_18000ul.json') as labware_file:
    stocks_def = json.load(labware_file)
    stocks = protocol.load_labware_from_definition(stocks_def, location=3)

plate = protocol.load_labware(
    load_name="corning_96_wellplate_360ul_flat",
    location=4)

# %%
tiprack_20_wells = [well for row in tiprack_20.rows() for well in row]
tiprack_300_wells = [well for row in tiprack_300.rows() for well in row]
stocks_wells = [well for row in stocks.rows() for well in row]
plate_wells = [well for row in plate.rows() for well in row]

# %%
def synthesize(stock_index, ds):
    """ Synthesize AuNP by mixing components

    stock_index : index of the stock to add (int)
    ds : a pandas dataseries with volumes to be added. 
    """
    p20.pick_up_tip(tiprack_20_wells[int(stock_index)])
    p300.pick_up_tip(tiprack_300_wells[int(stock_index)])
    has_used_p20, has_used_p300 = False, False
    for index, value in ds.items():
        if value<20:
            pipette = p20 
            has_used_p20 = True
        else:
            pipette = p300
            has_used_p300 = True
        source_well = stocks_wells[int(stock_index)]
        target_well = plate_wells[int(index)]
        print("Dispensing %s of %d from %s into well %s "%(ds.name, value, source_well.well_name, target_well.well_name)) #,end='\r', flush=False)
        pipette.aspirate(value, source_well)
        pipette.dispense(value, target_well.top())
        if not stock_index==0:
            pipette.blow_out()

    if has_used_p20:
        p20.drop_tip()
    else:
        p20.return_tip()

    if has_used_p300:
        p300.drop_tip()
    else:
        p300.return_tip()

# %%
volume_df = pd.read_csv('./grid_volumes.csv')
for stock_index,(_, stock_vol_series)  in enumerate(volume_df.items()):
    synthesize(stock_index, stock_vol_series)
# Out:
# Dispensing CTAB of 96 from A1 into well A1
# Dispensing CTAB of 96 from A1 into well A2
# Dispensing CTAB of 96 from A1 into well A3
# Dispensing CTAB of 96 from A1 into well A4
# Dispensing CTAB of 96 from A1 into well A5
# Dispensing CTAB of 96 from A1 into well A6
# Dispensing CTAB of 96 from A1 into well A7
# Dispensing CTAB of 96 from A1 into well A8
# Dispensing CTAB of 96 from A1 into well A9
# Dispensing CTAB of 96 from A1 into well A10
# Dispensing CTAB of 96 from A1 into well A11
# Dispensing CTAB of 96 from A1 into well A12
# Dispensing CTAB of 96 from A1 into well B1
# Dispensing CTAB of 96 from A1 into well B2
# Dispensing CTAB of 96 from A1 into well B3
# Dispensing CTAB of 96 from A1 into well B4
# Dispensing CTAB of 96 from A1 into well B5
# Dispensing CTAB of 96 from A1 into well B6
# Dispensing CTAB of 96 from A1 into well B7
# Dispensing CTAB of 96 from A1 into well B8
# Dispensing CTAB of 96 from A1 into well B9
# Dispensing CTAB of 96 from A1 into well B10
# Dispensing CTAB of 96 from A1 into well B11
# Dispensing CTAB of 96 from A1 into well B12
# Dispensing CTAB of 96 from A1 into well C1
# Dispensing CTAB of 96 from A1 into well C2
# Dispensing CTAB of 96 from A1 into well C3
# Dispensing CTAB of 96 from A1 into well C4
# Dispensing CTAB of 96 from A1 into well C5
# Dispensing CTAB of 96 from A1 into well C6
# Dispensing CTAB of 96 from A1 into well C7
# Dispensing CTAB of 96 from A1 into well C8
# Dispensing CTAB of 96 from A1 into well C9
# Dispensing CTAB of 96 from A1 into well C10
# Dispensing CTAB of 96 from A1 into well C11
# Dispensing CTAB of 96 from A1 into well C12
# Dispensing CTAB of 96 from A1 into well D1
# Dispensing CTAB of 96 from A1 into well D2
# Dispensing CTAB of 96 from A1 into well D3
# Dispensing CTAB of 96 from A1 into well D4
# Dispensing CTAB of 96 from A1 into well D5
# Dispensing CTAB of 96 from A1 into well D6
# Dispensing CTAB of 96 from A1 into well D7
# Dispensing CTAB of 96 from A1 into well D8
# Dispensing CTAB of 96 from A1 into well D9
# Dispensing CTAB of 96 from A1 into well D10
# Dispensing CTAB of 96 from A1 into well D11
# Dispensing CTAB of 96 from A1 into well D12
# Dispensing CTAB of 96 from A1 into well E1
# Dispensing CTAB of 96 from A1 into well E2
# Dispensing CTAB of 96 from A1 into well E3
# Dispensing CTAB of 96 from A1 into well E4
# Dispensing CTAB of 96 from A1 into well E5
# Dispensing CTAB of 96 from A1 into well E6
# Dispensing CTAB of 96 from A1 into well E7
# Dispensing CTAB of 96 from A1 into well E8
# Dispensing CTAB of 96 from A1 into well E9
# Dispensing CTAB of 96 from A1 into well E10
# Dispensing CTAB of 96 from A1 into well E11
# Dispensing CTAB of 96 from A1 into well E12
# Dispensing CTAB of 96 from A1 into well F1
# Dispensing CTAB of 96 from A1 into well F2
# Dispensing CTAB of 96 from A1 into well F3
# Dispensing CTAB of 96 from A1 into well F4
# Dispensing CTAB of 96 from A1 into well F5
# Dispensing CTAB of 96 from A1 into well F6
# Dispensing CTAB of 96 from A1 into well F7
# Dispensing CTAB of 96 from A1 into well F8
# Dispensing CTAB of 96 from A1 into well F9
# Dispensing CTAB of 96 from A1 into well F10
# Dispensing CTAB of 96 from A1 into well F11
# Dispensing CTAB of 96 from A1 into well F12
# Dispensing CTAB of 96 from A1 into well G1
# Dispensing CTAB of 96 from A1 into well G2
# Dispensing CTAB of 96 from A1 into well G3
# Dispensing CTAB of 96 from A1 into well G4
# Dispensing CTAB of 96 from A1 into well G5
# Dispensing CTAB of 96 from A1 into well G6
# Dispensing CTAB of 96 from A1 into well G7
# Dispensing CTAB of 96 from A1 into well G8
# Dispensing CTAB of 96 from A1 into well G9
# Dispensing CTAB of 96 from A1 into well G10
# Dispensing CTAB of 96 from A1 into well G11
# Dispensing CTAB of 96 from A1 into well G12
# Dispensing CTAB of 96 from A1 into well H1
# Dispensing CTAB of 96 from A1 into well H2
# Dispensing CTAB of 96 from A1 into well H3
# Dispensing CTAB of 96 from A1 into well H4
# Dispensing CTAB of 96 from A1 into well H5
# Dispensing CTAB of 96 from A1 into well H6
# Dispensing CTAB of 96 from A1 into well H7
# Dispensing CTAB of 96 from A1 into well H8
# Dispensing CTAB of 96 from A1 into well H9
# Dispensing CTAB of 96 from A1 into well H10
# Dispensing CTAB of 96 from A1 into well H11
# Dispensing CTAB of 96 from A1 into well H12
# Dispensing Water of 121 from A2 into well A1
# Dispensing Water of 118 from A2 into well A2
# Dispensing Water of 115 from A2 into well A3
# Dispensing Water of 111 from A2 into well A4
# Dispensing Water of 108 from A2 into well A5
# Dispensing Water of 105 from A2 into well A6
# Dispensing Water of 102 from A2 into well A7
# Dispensing Water of 99 from A2 into well A8
# Dispensing Water of 96 from A2 into well A9
# Dispensing Water of 92 from A2 into well A10
# Dispensing Water of 89 from A2 into well A11
# Dispensing Water of 86 from A2 into well A12
# Dispensing Water of 116 from A2 into well B1
# Dispensing Water of 113 from A2 into well B2
# Dispensing Water of 110 from A2 into well B3
# Dispensing Water of 106 from A2 into well B4
# Dispensing Water of 103 from A2 into well B5
# Dispensing Water of 100 from A2 into well B6
# Dispensing Water of 97 from A2 into well B7
# Dispensing Water of 94 from A2 into well B8
# Dispensing Water of 91 from A2 into well B9
# Dispensing Water of 87 from A2 into well B10
# Dispensing Water of 84 from A2 into well B11
# Dispensing Water of 81 from A2 into well B12
# Dispensing Water of 111 from A2 into well C1
# Dispensing Water of 108 from A2 into well C2
# Dispensing Water of 105 from A2 into well C3
# Dispensing Water of 101 from A2 into well C4
# Dispensing Water of 98 from A2 into well C5
# Dispensing Water of 95 from A2 into well C6
# Dispensing Water of 92 from A2 into well C7
# Dispensing Water of 89 from A2 into well C8
# Dispensing Water of 86 from A2 into well C9
# Dispensing Water of 82 from A2 into well C10
# Dispensing Water of 79 from A2 into well C11
# Dispensing Water of 76 from A2 into well C12
# Dispensing Water of 106 from A2 into well D1
# Dispensing Water of 103 from A2 into well D2
# Dispensing Water of 100 from A2 into well D3
# Dispensing Water of 96 from A2 into well D4
# Dispensing Water of 93 from A2 into well D5
# Dispensing Water of 90 from A2 into well D6
# Dispensing Water of 87 from A2 into well D7
# Dispensing Water of 84 from A2 into well D8
# Dispensing Water of 81 from A2 into well D9
# Dispensing Water of 77 from A2 into well D10
# Dispensing Water of 74 from A2 into well D11
# Dispensing Water of 71 from A2 into well D12
# Dispensing Water of 101 from A2 into well E1
# Dispensing Water of 98 from A2 into well E2
# Dispensing Water of 95 from A2 into well E3
# Dispensing Water of 91 from A2 into well E4
# Dispensing Water of 88 from A2 into well E5
# Dispensing Water of 85 from A2 into well E6
# Dispensing Water of 82 from A2 into well E7
# Dispensing Water of 79 from A2 into well E8
# Dispensing Water of 76 from A2 into well E9
# Dispensing Water of 72 from A2 into well E10
# Dispensing Water of 69 from A2 into well E11
# Dispensing Water of 66 from A2 into well E12
# Dispensing Water of 96 from A2 into well F1
# Dispensing Water of 93 from A2 into well F2
# Dispensing Water of 90 from A2 into well F3
# Dispensing Water of 86 from A2 into well F4
# Dispensing Water of 83 from A2 into well F5
# Dispensing Water of 80 from A2 into well F6
# Dispensing Water of 77 from A2 into well F7
# Dispensing Water of 74 from A2 into well F8
# Dispensing Water of 71 from A2 into well F9
# Dispensing Water of 67 from A2 into well F10
# Dispensing Water of 64 from A2 into well F11
# Dispensing Water of 61 from A2 into well F12
# Dispensing Water of 91 from A2 into well G1
# Dispensing Water of 88 from A2 into well G2
# Dispensing Water of 85 from A2 into well G3
# Dispensing Water of 81 from A2 into well G4
# Dispensing Water of 78 from A2 into well G5
# Dispensing Water of 75 from A2 into well G6
# Dispensing Water of 72 from A2 into well G7
# Dispensing Water of 69 from A2 into well G8
# Dispensing Water of 66 from A2 into well G9
# Dispensing Water of 62 from A2 into well G10
# Dispensing Water of 59 from A2 into well G11
# Dispensing Water of 56 from A2 into well G12
# Dispensing Water of 86 from A2 into well H1
# Dispensing Water of 83 from A2 into well H2
# Dispensing Water of 80 from A2 into well H3
# Dispensing Water of 76 from A2 into well H4
# Dispensing Water of 73 from A2 into well H5
# Dispensing Water of 70 from A2 into well H6
# Dispensing Water of 67 from A2 into well H7
# Dispensing Water of 64 from A2 into well H8
# Dispensing Water of 61 from A2 into well H9
# Dispensing Water of 57 from A2 into well H10
# Dispensing Water of 54 from A2 into well H11
# Dispensing Water of 51 from A2 into well H12
# Dispensing GCH of 59 from A3 into well A1
# Dispensing GCH of 59 from A3 into well A2
# Dispensing GCH of 59 from A3 into well A3
# Dispensing GCH of 59 from A3 into well A4
# Dispensing GCH of 59 from A3 into well A5
# Dispensing GCH of 59 from A3 into well A6
# Dispensing GCH of 59 from A3 into well A7
# Dispensing GCH of 59 from A3 into well A8
# Dispensing GCH of 59 from A3 into well A9
# Dispensing GCH of 59 from A3 into well A10
# Dispensing GCH of 59 from A3 into well A11
# Dispensing GCH of 59 from A3 into well A12
# Dispensing GCH of 59 from A3 into well B1
# Dispensing GCH of 59 from A3 into well B2
# Dispensing GCH of 59 from A3 into well B3
# Dispensing GCH of 59 from A3 into well B4
# Dispensing GCH of 59 from A3 into well B5
# Dispensing GCH of 59 from A3 into well B6
# Dispensing GCH of 59 from A3 into well B7
# Dispensing GCH of 59 from A3 into well B8
# Dispensing GCH of 59 from A3 into well B9
# Dispensing GCH of 59 from A3 into well B10
# Dispensing GCH of 59 from A3 into well B11
# Dispensing GCH of 59 from A3 into well B12
# Dispensing GCH of 59 from A3 into well C1
# Dispensing GCH of 59 from A3 into well C2
# Dispensing GCH of 59 from A3 into well C3
# Dispensing GCH of 59 from A3 into well C4
# Dispensing AA of 0 from A4 into well A2
# Dispensing AA of 0 from A4 into well A3
# Dispensing AA of 0 from A4 into well A4
# Dispensing AA of 0 from A4 into well A5
# Dispensing AA of 0 from A4 into well A6
# Dispensing AA of 0 from A4 into well A7
# Dispensing AA of 0 from A4 into well A8
# Dispensing AA of 0 from A4 into well A9
# Dispensing AA of 0 from A4 into well A10
# Dispensing AA of 0 from A4 into well A11
# Dispensing AA of 0 from A4 into well A12
# Dispensing AA of 5 from A4 into well B1
# Dispensing AA of 5 from A4 into well B2
# Dispensing AA of 5 from A4 into well B3
# Dispensing AA of 5 from A4 into well B4
# Dispensing AA of 5 from A4 into well B5
# Dispensing AA of 5 from A4 into well B6
# Dispensing AA of 5 from A4 into well B7
# Dispensing AA of 5 from A4 into well B8
# Dispensing AA of 5 from A4 into well B9
# Dispensing AA of 5 from A4 into well B10
# Dispensing AA of 5 from A4 into well B11
# Dispensing AA of 5 from A4 into well B12
# Dispensing AA of 10 from A4 into well C1
# Dispensing AA of 10 from A4 into well C2
# Dispensing AA of 10 from A4 into well C3
# Dispensing AA of 10 from A4 into well C4
# Dispensing AA of 10 from A4 into well C5
# Dispensing AA of 10 from A4 into well C6
# Dispensing AA of 10 from A4 into well C7
# Dispensing AA of 10 from A4 into well C8
# Dispensing AA of 10 from A4 into well C9
# Dispensing AA of 10 from A4 into well C10
# Dispensing AA of 10 from A4 into well C11
# Dispensing AA of 10 from A4 into well C12
# Dispensing AA of 15 from A4 into well D1
# Dispensing AA of 15 from A4 into well D2
# Dispensing AA of 15 from A4 into well D3
# Dispensing AA of 15 from A4 into well D4
# Dispensing AA of 15 from A4 into well D5
# Dispensing AA of 15 from A4 into well D6
# Dispensing AA of 15 from A4 into well D7
# Dispensing AA of 15 from A4 into well D8
# Dispensing AA of 15 from A4 into well D9
# Dispensing AA of 15 from A4 into well D10
# Dispensing AA of 15 from A4 into well D11
# Dispensing AA of 15 from A4 into well D12
# Dispensing AA of 20 from A4 into well E1
# Dispensing AA of 20 from A4 into well E2
# Dispensing AA of 20 from A4 into well E3
# Dispensing AA of 20 from A4 into well E4
# Dispensing AA of 20 from A4 into well E5
# Dispensing AA of 20 from A4 into well E6
# Dispensing AA of 20 from A4 into well E7
# Dispensing AA of 20 from A4 into well E8
# Dispensing AA of 20 from A4 into well E9
# Dispensing AA of 20 from A4 into well E10
# Dispensing AA of 20 from A4 into well E11
# Dispensing AA of 20 from A4 into well E12
# Dispensing AA of 25 from A4 into well F1
# Dispensing AA of 25 from A4 into well F2
# Dispensing AA of 25 from A4 into well F3
# Dispensing AA of 25 from A4 into well F4
# Dispensing AA of 25 from A4 into well F5
# Dispensing AA of 25 from A4 into well F6
# Dispensing AA of 25 from A4 into well F7
# Dispensing AA of 25 from A4 into well F8
# Dispensing AA of 25 from A4 into well F9
# Dispensing AA of 25 from A4 into well F10
# Dispensing AA of 25 from A4 into well F11
# Dispensing AA of 25 from A4 into well F12
# Dispensing AA of 30 from A4 into well G1
# Dispensing AA of 30 from A4 into well G2
# Dispensing AA of 30 from A4 into well G3
# Dispensing AA of 30 from A4 into well G4
# Dispensing AA of 30 from A4 into well G5
# Dispensing AA of 30 from A4 into well G6
# Dispensing AA of 30 from A4 into well G7
# Dispensing AA of 30 from A4 into well G8
# Dispensing AA of 30 from A4 into well G9
# Dispensing AA of 30 from A4 into well G10
# Dispensing AA of 30 from A4 into well G11
# Dispensing AA of 30 from A4 into well G12
# Dispensing AA of 35 from A4 into well H1
# Dispensing AA of 35 from A4 into well H2
# Dispensing AA of 35 from A4 into well H3
# Dispensing AA of 35 from A4 into well H4
# Dispensing AA of 35 from A4 into well H5
# Dispensing AA of 35 from A4 into well H6
# Dispensing AA of 35 from A4 into well H7
# Dispensing AA of 35 from A4 into well H8
# Dispensing AA of 35 from A4 into well H9
# Dispensing AA of 35 from A4 into well H10
# Dispensing AA of 35 from A4 into well H11
# Dispensing AA of 35 from A4 into well H12
# Dispensing SN of 0 from B1 into well A1
# Dispensing SN of 3 from B1 into well A2
# Dispensing SN of 6 from B1 into well A3
# Dispensing SN of 10 from B1 into well A4
# Dispensing SN of 13 from B1 into well A5
# Dispensing SN of 16 from B1 into well A6
# Dispensing SN of 19 from B1 into well A7
# Dispensing SN of 22 from B1 into well A8
# Dispensing SN of 25 from B1 into well A9
# Dispensing SN of 29 from B1 into well A10
# Dispensing SN of 32 from B1 into well A11
# Dispensing SN of 35 from B1 into well A12
# Dispensing SN of 0 from B1 into well B1
# Dispensing SN of 3 from B1 into well B2
# Dispensing SN of 6 from B1 into well B3
# Dispensing SN of 10 from B1 into well B4
# Dispensing SN of 13 from B1 into well B5
# Dispensing SN of 16 from B1 into well B6
# Dispensing SN of 19 from B1 into well B7
# Dispensing SN of 22 from B1 into well B8
# Dispensing SN of 25 from B1 into well B9
# Dispensing SN of 29 from B1 into well B10
# Dispensing SN of 32 from B1 into well B11
# Dispensing SN of 35 from B1 into well B12
# Dispensing SN of 0 from B1 into well C1
# Dispensing SN of 3 from B1 into well C2
# Dispensing SN of 6 from B1 into well C3
# Dispensing SN of 10 from B1 into well C4
# Dispensing SN of 13 from B1 into well C5
# Dispensing SN of 16 from B1 into well C6
# Dispensing SN of 19 from B1 into well C7
# Dispensing SN of 22 from B1 into well C8
# Dispensing SN of 25 from B1 into well C9
# Dispensing SN of 29 from B1 into well C10
# Dispensing SN of 32 from B1 into well C11
# Dispensing SN of 35 from B1 into well C12
# Dispensing SN of 0 from B1 into well D1
# Dispensing SN of 3 from B1 into well D2
# Dispensing SN of 6 from B1 into well D3
# Dispensing SN of 10 from B1 into well D4
# Dispensing SN of 13 from B1 into well D5
# Dispensing SN of 16 from B1 into well D6
# Dispensing SN of 19 from B1 into well D7
# Dispensing SN of 22 from B1 into well D8
# Dispensing SN of 25 from B1 into well D9
# Dispensing SN of 29 from B1 into well D10
# Dispensing SN of 32 from B1 into well D11
# Dispensing SN of 35 from B1 into well D12
# Dispensing SN of 0 from B1 into well E1
# Dispensing SN of 3 from B1 into well E2
# Dispensing SN of 6 from B1 into well E3
# Dispensing SN of 10 from B1 into well E4
# Dispensing SN of 13 from B1 into well E5
# Dispensing SN of 16 from B1 into well E6
# Dispensing SN of 19 from B1 into well E7
# Dispensing SN of 22 from B1 into well E8
# Dispensing SN of 25 from B1 into well E9
# Dispensing SN of 29 from B1 into well E10
# Dispensing SN of 32 from B1 into well E11
# Dispensing SN of 35 from B1 into well E12
# Dispensing SN of 0 from B1 into well F1
# Dispensing SN of 3 from B1 into well F2
# Dispensing SN of 6 from B1 into well F3
# Dispensing SN of 10 from B1 into well F4
# Dispensing SN of 13 from B1 into well F5
# Dispensing SN of 16 from B1 into well F6
# Dispensing SN of 19 from B1 into well F7
# Dispensing SN of 22 from B1 into well F8
# Dispensing SN of 25 from B1 into well F9
# Dispensing SN of 29 from B1 into well F10
# Dispensing SN of 32 from B1 into well F11
# Dispensing SN of 35 from B1 into well F12
# Dispensing SN of 0 from B1 into well G1
# Dispensing SN of 3 from B1 into well G2
# Dispensing SN of 6 from B1 into well G3
# Dispensing SN of 10 from B1 into well G4
# Dispensing SN of 13 from B1 into well G5
# Dispensing SN of 16 from B1 into well G6
# Dispensing SN of 19 from B1 into well G7
# Dispensing SN of 22 from B1 into well G8
# Dispensing SN of 25 from B1 into well G9
# Dispensing SN of 29 from B1 into well G10
# Dispensing SN of 32 from B1 into well G11
# Dispensing SN of 35 from B1 into well G12
# Dispensing SN of 0 from B1 into well H1
# Dispensing SN of 3 from B1 into well H2
# Dispensing SN of 6 from B1 into well H3
# Dispensing SN of 10 from B1 into well H4
# Dispensing SN of 13 from B1 into well H5
# Dispensing SN of 16 from B1 into well H6
# Dispensing SN of 19 from B1 into well H7
# Dispensing SN of 22 from B1 into well H8
# Dispensing SN of 25 from B1 into well H9
# Dispensing SN of 29 from B1 into well H10
# Dispensing SN of 32 from B1 into well H11
# Dispensing SN of 35 from B1 into well H12
# Dispensing GS of 24 from B2 into well A1
# Dispensing GS of 24 from B2 into well A2
# Dispensing GS of 24 from B2 into well A3
# Dispensing GS of 24 from B2 into well A4
# Dispensing GS of 24 from B2 into well A5
# Dispensing GS of 24 from B2 into well A6
# Dispensing GS of 24 from B2 into well A7
# Dispensing GS of 24 from B2 into well A8
# Dispensing GS of 24 from B2 into well A9
# Dispensing GS of 24 from B2 into well A10
# Dispensing GS of 24 from B2 into well A11
# Dispensing GS of 24 from B2 into well A12
# Dispensing GS of 24 from B2 into well B1
# Dispensing GS of 24 from B2 into well B2
# Dispensing GS of 24 from B2 into well B3
# Dispensing GS of 24 from B2 into well B4
# Dispensing GS of 24 from B2 into well B5
# Dispensing GS of 24 from B2 into well B6
# Dispensing GS of 24 from B2 into well B7
# Dispensing GS of 24 from B2 into well B8
# Dispensing GS of 24 from B2 into well B9
# Dispensing GS of 24 from B2 into well B10
# Dispensing GS of 24 from B2 into well B11
# Dispensing GS of 24 from B2 into well B12
