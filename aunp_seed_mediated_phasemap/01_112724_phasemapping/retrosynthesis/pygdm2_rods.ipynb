# %%
from pyGDM2 import structures
from pyGDM2 import materials
from pyGDM2 import fields
from pyGDM2 import propagators
from pyGDM2 import core
from pyGDM2 import linear
from pyGDM2 import tools
import numpy as np 
import matplotlib.pyplot as plt

# %%
target_radius = 2.5 # in nm
target_length = 20 # in nm
step = 1 # in nm
geometry = structures.nanorod(step, 
                              R = np.ceil(target_radius/step),
                              L = np.ceil(target_length/step),
                              mesh='hex'
                              ) 

material = materials.gold()
struct = structures.struct(step, geometry, material)

field_generator = fields.plane_wave
wavelengths = np.linspace(400, 900, 101)
field_kwargs = dict(theta=[0], inc_angle=180)

efield = fields.efield(field_generator, wavelengths=wavelengths, kwargs=field_kwargs)
n1 = n2 = 1.33
dyads = propagators.DyadsQuasistatic123(n1=n1, n2=n2)
sim = core.simulation(struct, efield, dyads)
# Out:
# structure initialization - automatic mesh detection: hex
# structure initialization - consistency check: 921/921 dipoles valid

# %%
## --- run the simulation
sim.scatter()
# Out:
# timing for wl=400.00nm - setup: EE 112.9ms, inv.: 600.9ms, repropa.: 37.2ms (1 field configs), tot: 751.5ms
# timing for wl=405.00nm - setup: EE 143.1ms, inv.: 829.8ms, repropa.: 59.2ms (1 field configs), tot: 1032.6ms
# timing for wl=410.00nm - setup: EE 109.0ms, inv.: 684.2ms, repropa.: 61.8ms (1 field configs), tot: 855.6ms
# timing for wl=415.00nm - setup: EE 109.6ms, inv.: 600.3ms, repropa.: 32.5ms (1 field configs), tot: 744.1ms
# timing for wl=420.00nm - setup: EE 94.9ms, inv.: 615.8ms, repropa.: 55.4ms (1 field configs), tot: 767.1ms
# timing for wl=425.00nm - setup: EE 113.0ms, inv.: 650.9ms, repropa.: 34.5ms (1 field configs), tot: 798.6ms
# timing for wl=430.00nm - setup: EE 130.8ms, inv.: 649.9ms, repropa.: 41.4ms (1 field configs), tot: 822.6ms
# timing for wl=435.00nm - setup: EE 126.9ms, inv.: 611.2ms, repropa.: 63.9ms (1 field configs), tot: 802.4ms
# timing for wl=440.00nm - setup: EE 111.3ms, inv.: 603.2ms, repropa.: 39.7ms (1 field configs), tot: 754.6ms
# timing for wl=445.00nm - setup: EE 132.8ms, inv.: 641.6ms, repropa.: 39.7ms (1 field configs), tot: 814.5ms
# timing for wl=450.00nm - setup: EE 106.1ms, inv.: 613.3ms, repropa.: 41.4ms (1 field configs), tot: 761.0ms
# timing for wl=455.00nm - setup: EE 124.7ms, inv.: 595.3ms, repropa.: 52.5ms (1 field configs), tot: 772.8ms
# timing for wl=460.00nm - setup: EE 113.4ms, inv.: 663.8ms, repropa.: 40.0ms (1 field configs), tot: 817.8ms
# timing for wl=465.00nm - setup: EE 129.5ms, inv.: 583.2ms, repropa.: 40.0ms (1 field configs), tot: 753.0ms
# timing for wl=470.00nm - setup: EE 107.6ms, inv.: 608.9ms, repropa.: 63.1ms (1 field configs), tot: 779.8ms
# timing for wl=475.00nm - setup: EE 97.0ms, inv.: 643.8ms, repropa.: 40.2ms (1 field configs), tot: 781.4ms
# timing for wl=480.00nm - setup: EE 132.2ms, inv.: 617.4ms, repropa.: 53.4ms (1 field configs), tot: 803.2ms
# timing for wl=485.00nm - setup: EE 141.8ms, inv.: 593.9ms, repropa.: 39.5ms (1 field configs), tot: 775.4ms
# timing for wl=490.00nm - setup: EE 120.4ms, inv.: 624.2ms, repropa.: 39.4ms (1 field configs), tot: 784.3ms
# timing for wl=495.00nm - setup: EE 112.5ms, inv.: 715.1ms, repropa.: 52.9ms (1 field configs), tot: 880.8ms
# timing for wl=500.00nm - setup: EE 182.2ms, inv.: 636.5ms, repropa.: 49.5ms (1 field configs), tot: 869.0ms
# timing for wl=505.00nm - setup: EE 121.3ms, inv.: 613.7ms, repropa.: 57.4ms (1 field configs), tot: 792.7ms
# timing for wl=510.00nm - setup: EE 126.8ms, inv.: 641.7ms, repropa.: 44.4ms (1 field configs), tot: 813.1ms
# timing for wl=515.00nm - setup: EE 112.4ms, inv.: 637.1ms, repropa.: 34.8ms (1 field configs), tot: 784.7ms
# timing for wl=520.00nm - setup: EE 110.5ms, inv.: 654.4ms, repropa.: 46.9ms (1 field configs), tot: 812.1ms
# timing for wl=525.00nm - setup: EE 111.7ms, inv.: 614.6ms, repropa.: 53.4ms (1 field configs), tot: 780.0ms
# timing for wl=530.00nm - setup: EE 106.9ms, inv.: 658.6ms, repropa.: 50.0ms (1 field configs), tot: 815.8ms
# timing for wl=535.00nm - setup: EE 139.5ms, inv.: 612.7ms, repropa.: 31.5ms (1 field configs), tot: 784.0ms
# timing for wl=540.00nm - setup: EE 127.6ms, inv.: 717.7ms, repropa.: 45.0ms (1 field configs), tot: 890.6ms
# timing for wl=545.00nm - setup: EE 98.7ms, inv.: 641.8ms, repropa.: 38.8ms (1 field configs), tot: 779.6ms
# timing for wl=550.00nm - setup: EE 109.8ms, inv.: 629.2ms, repropa.: 60.8ms (1 field configs), tot: 800.1ms
# timing for wl=555.00nm - setup: EE 105.5ms, inv.: 625.2ms, repropa.: 34.8ms (1 field configs), tot: 765.7ms
# timing for wl=560.00nm - setup: EE 111.7ms, inv.: 646.5ms, repropa.: 65.1ms (1 field configs), tot: 825.3ms
# timing for wl=565.00nm - setup: EE 131.4ms, inv.: 764.8ms, repropa.: 31.2ms (1 field configs), tot: 927.6ms
# timing for wl=570.00nm - setup: EE 104.6ms, inv.: 642.9ms, repropa.: 56.9ms (1 field configs), tot: 804.7ms
# timing for wl=575.00nm - setup: EE 106.6ms, inv.: 663.6ms, repropa.: 53.6ms (1 field configs), tot: 824.0ms
# timing for wl=580.00nm - setup: EE 117.7ms, inv.: 661.6ms, repropa.: 54.5ms (1 field configs), tot: 834.2ms
# timing for wl=585.00nm - setup: EE 113.9ms, inv.: 679.7ms, repropa.: 33.6ms (1 field configs), tot: 827.5ms
# timing for wl=590.00nm - setup: EE 114.2ms, inv.: 606.4ms, repropa.: 56.5ms (1 field configs), tot: 778.7ms
# timing for wl=595.00nm - setup: EE 121.7ms, inv.: 628.4ms, repropa.: 35.8ms (1 field configs), tot: 786.2ms
# timing for wl=600.00nm - setup: EE 114.3ms, inv.: 711.3ms, repropa.: 47.8ms (1 field configs), tot: 873.7ms
# timing for wl=605.00nm - setup: EE 121.9ms, inv.: 631.1ms, repropa.: 49.0ms (1 field configs), tot: 802.6ms
# timing for wl=610.00nm - setup: EE 126.1ms, inv.: 650.8ms, repropa.: 87.6ms (1 field configs), tot: 864.8ms
# timing for wl=615.00nm - setup: EE 155.6ms, inv.: 668.5ms, repropa.: 63.4ms (1 field configs), tot: 888.1ms
# timing for wl=620.00nm - setup: EE 117.7ms, inv.: 645.4ms, repropa.: 32.6ms (1 field configs), tot: 796.0ms
# timing for wl=625.00nm - setup: EE 114.8ms, inv.: 603.4ms, repropa.: 51.6ms (1 field configs), tot: 770.2ms
# timing for wl=630.00nm - setup: EE 103.4ms, inv.: 615.5ms, repropa.: 46.7ms (1 field configs), tot: 772.0ms
# timing for wl=635.00nm - setup: EE 123.0ms, inv.: 659.5ms, repropa.: 52.2ms (1 field configs), tot: 835.3ms
# timing for wl=640.00nm - setup: EE 141.0ms, inv.: 851.6ms, repropa.: 39.8ms (1 field configs), tot: 1032.8ms
# timing for wl=645.00nm - setup: EE 113.6ms, inv.: 660.0ms, repropa.: 48.0ms (1 field configs), tot: 823.0ms
# timing for wl=650.00nm - setup: EE 122.8ms, inv.: 582.2ms, repropa.: 40.2ms (1 field configs), tot: 745.5ms
# timing for wl=655.00nm - setup: EE 122.8ms, inv.: 603.5ms, repropa.: 47.9ms (1 field configs), tot: 774.6ms
# timing for wl=660.00nm - setup: EE 135.2ms, inv.: 631.0ms, repropa.: 44.5ms (1 field configs), tot: 811.0ms
# timing for wl=665.00nm - setup: EE 111.9ms, inv.: 620.3ms, repropa.: 49.2ms (1 field configs), tot: 782.0ms
# timing for wl=670.00nm - setup: EE 109.5ms, inv.: 604.4ms, repropa.: 50.9ms (1 field configs), tot: 765.0ms
# timing for wl=675.00nm - setup: EE 107.6ms, inv.: 590.8ms, repropa.: 36.3ms (1 field configs), tot: 735.1ms
# timing for wl=680.00nm - setup: EE 110.5ms, inv.: 595.6ms, repropa.: 59.2ms (1 field configs), tot: 765.6ms
# timing for wl=685.00nm - setup: EE 116.8ms, inv.: 617.8ms, repropa.: 60.6ms (1 field configs), tot: 795.5ms
# timing for wl=690.00nm - setup: EE 111.3ms, inv.: 600.2ms, repropa.: 41.6ms (1 field configs), tot: 753.4ms
# timing for wl=695.00nm - setup: EE 106.7ms, inv.: 592.8ms, repropa.: 57.1ms (1 field configs), tot: 756.8ms
# timing for wl=700.00nm - setup: EE 129.1ms, inv.: 573.8ms, repropa.: 48.7ms (1 field configs), tot: 751.9ms
# timing for wl=705.00nm - setup: EE 117.7ms, inv.: 663.3ms, repropa.: 44.0ms (1 field configs), tot: 825.3ms
# timing for wl=710.00nm - setup: EE 111.1ms, inv.: 621.3ms, repropa.: 48.1ms (1 field configs), tot: 780.8ms
# timing for wl=715.00nm - setup: EE 117.9ms, inv.: 660.2ms, repropa.: 27.2ms (1 field configs), tot: 805.5ms
# timing for wl=720.00nm - setup: EE 113.8ms, inv.: 672.5ms, repropa.: 49.7ms (1 field configs), tot: 836.5ms
# timing for wl=725.00nm - setup: EE 114.2ms, inv.: 602.2ms, repropa.: 50.9ms (1 field configs), tot: 767.7ms
# timing for wl=730.00nm - setup: EE 124.3ms, inv.: 670.7ms, repropa.: 34.4ms (1 field configs), tot: 829.6ms
# timing for wl=735.00nm - setup: EE 96.7ms, inv.: 656.6ms, repropa.: 48.1ms (1 field configs), tot: 801.8ms
# timing for wl=740.00nm - setup: EE 113.5ms, inv.: 597.0ms, repropa.: 59.3ms (1 field configs), tot: 770.3ms
# timing for wl=745.00nm - setup: EE 103.3ms, inv.: 590.1ms, repropa.: 37.7ms (1 field configs), tot: 731.7ms
# timing for wl=750.00nm - setup: EE 131.9ms, inv.: 598.0ms, repropa.: 60.0ms (1 field configs), tot: 790.2ms
# timing for wl=755.00nm - setup: EE 100.8ms, inv.: 593.8ms, repropa.: 66.2ms (1 field configs), tot: 761.0ms
# timing for wl=760.00nm - setup: EE 113.4ms, inv.: 559.2ms, repropa.: 55.1ms (1 field configs), tot: 727.9ms
# timing for wl=765.00nm - setup: EE 110.9ms, inv.: 595.2ms, repropa.: 32.5ms (1 field configs), tot: 739.0ms
# timing for wl=770.00nm - setup: EE 98.7ms, inv.: 677.6ms, repropa.: 38.7ms (1 field configs), tot: 815.3ms
# timing for wl=775.00nm - setup: EE 105.0ms, inv.: 609.3ms, repropa.: 38.8ms (1 field configs), tot: 753.5ms
# timing for wl=780.00nm - setup: EE 122.4ms, inv.: 645.7ms, repropa.: 60.5ms (1 field configs), tot: 829.1ms
# timing for wl=785.00nm - setup: EE 104.8ms, inv.: 629.8ms, repropa.: 39.3ms (1 field configs), tot: 774.3ms
# timing for wl=790.00nm - setup: EE 94.9ms, inv.: 643.3ms, repropa.: 51.1ms (1 field configs), tot: 789.5ms
# timing for wl=795.00nm - setup: EE 135.9ms, inv.: 621.7ms, repropa.: 32.0ms (1 field configs), tot: 789.9ms
# timing for wl=800.00nm - setup: EE 98.2ms, inv.: 674.0ms, repropa.: 33.9ms (1 field configs), tot: 806.4ms
# timing for wl=805.00nm - setup: EE 138.5ms, inv.: 665.4ms, repropa.: 42.5ms (1 field configs), tot: 846.7ms
# timing for wl=810.00nm - setup: EE 124.5ms, inv.: 678.8ms, repropa.: 43.7ms (1 field configs), tot: 847.3ms
# timing for wl=815.00nm - setup: EE 130.2ms, inv.: 646.1ms, repropa.: 44.7ms (1 field configs), tot: 821.2ms
# timing for wl=820.00nm - setup: EE 98.7ms, inv.: 670.4ms, repropa.: 46.2ms (1 field configs), tot: 815.7ms
# timing for wl=825.00nm - setup: EE 96.8ms, inv.: 638.2ms, repropa.: 46.8ms (1 field configs), tot: 782.2ms
# timing for wl=830.00nm - setup: EE 109.6ms, inv.: 610.8ms, repropa.: 32.8ms (1 field configs), tot: 753.6ms
# timing for wl=835.00nm - setup: EE 111.5ms, inv.: 607.8ms, repropa.: 56.2ms (1 field configs), tot: 776.0ms
# timing for wl=840.00nm - setup: EE 134.2ms, inv.: 624.0ms, repropa.: 43.6ms (1 field configs), tot: 802.1ms
# timing for wl=845.00nm - setup: EE 112.2ms, inv.: 609.9ms, repropa.: 33.1ms (1 field configs), tot: 755.5ms
# timing for wl=850.00nm - setup: EE 80.2ms, inv.: 615.3ms, repropa.: 46.4ms (1 field configs), tot: 742.2ms
# timing for wl=855.00nm - setup: EE 133.5ms, inv.: 629.0ms, repropa.: 68.2ms (1 field configs), tot: 831.1ms
# timing for wl=860.00nm - setup: EE 125.0ms, inv.: 658.5ms, repropa.: 38.4ms (1 field configs), tot: 822.2ms
# timing for wl=865.00nm - setup: EE 112.4ms, inv.: 642.4ms, repropa.: 32.6ms (1 field configs), tot: 789.0ms
# timing for wl=870.00nm - setup: EE 106.9ms, inv.: 634.3ms, repropa.: 47.9ms (1 field configs), tot: 789.5ms
# timing for wl=875.00nm - setup: EE 104.1ms, inv.: 630.9ms, repropa.: 67.8ms (1 field configs), tot: 803.1ms
# timing for wl=880.00nm - setup: EE 104.1ms, inv.: 610.4ms, repropa.: 44.4ms (1 field configs), tot: 759.2ms
# timing for wl=885.00nm - setup: EE 111.0ms, inv.: 629.3ms, repropa.: 46.9ms (1 field configs), tot: 787.5ms
# timing for wl=890.00nm - setup: EE 119.5ms, inv.: 611.9ms, repropa.: 39.8ms (1 field configs), tot: 771.8ms
# timing for wl=895.00nm - setup: EE 124.1ms, inv.: 660.5ms, repropa.: 36.4ms (1 field configs), tot: 821.4ms
# timing for wl=900.00nm - setup: EE 112.8ms, inv.: 620.2ms, repropa.: 39.3ms (1 field configs), tot: 772.6ms
# 1

# %%
field_kwargs = tools.get_possible_field_params_spectra(sim)
for i, conf in enumerate(field_kwargs):
    print("config", i, ":", conf)
# Out:
# config 0 : {'inc_angle': 180, 'theta': 0}

# %%
wl, spectrum = tools.calculate_spectrum(sim, field_kwargs[0], linear.extinct)
area_geom = tools.get_geometric_cross_section(sim)

# %%
fig = plt.figure(figsize=(4*2, 4))
fig.subplots_adjust(wspace=0.5)
ax = fig.add_subplot(1,2,1, projection="3d")

ax.scatter(geometry[:,0], geometry[:,1], geometry[:,2])
ax.set_xlabel("x (nm)")
ax.set_ylabel("y (nm)")
ax.set_zlabel("z (nm)")

ax = fig.add_subplot(1,2,2)
ax.plot(wl, spectrum.T[0]/area_geom, 'g-', label='ext.')
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("cross section")
plt.savefig("./nanorods.png")
plt.show()

# %%
from scipy.interpolate import splev, splrep

y = spectrum.T[0]/area_geom
spline = splrep(wl, y)
xt = np.linspace(400, 900, 100) # upsample to 100 points
yt = splev(xt, spline)

fig, ax = plt.subplots()
ax.scatter(wl, y, s=10, color='k')
ax.plot(xt, yt)
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("cross section")
plt.show()

# %%
np.savez("./target_nanorod.npz", y=yt, x=xt)
